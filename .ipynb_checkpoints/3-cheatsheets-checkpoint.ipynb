# %% [markdown]
# # Unit 3: Applications

# %% [markdown]
# ## Areas and Volumes
#
# ### ***Process for finding areas and volumes***
# ### 1. Draw a picture
# ### 2. Identify limits of integration
# ### 3. Identify integrand
# ### 4. Integrate to solve (as needed)
#
# ### ***Volumes by slicing***
# ### The volume of a slice of bread is
# ## $$ dV = A(x) dx $$
# ### where $dx$ is the width of the slice, and $A(x)$ is the cross-sectional area. The volume of the entire loaf is:
# ## $$ V = \int A(x) dx $$
#
# ### ***Method of disks***
# ![Method of disks](img/disks.png)
# ### The method of disks gives the differential volume element for a curve rotated about the $x$-axis
# ## $$ dV = \pi y^2 dx $$
#
# ### ***Method of shells***
# ![Method of shells](img/shells.png)
# ### The method of shells for a curve $y=f(x)$ rotated about $y$-axis:
# ## $$ dV = 2 \pi x y dx $$
#
# ### ***Method of washers***
# ![Method of shells](img/washers.png)
# ### The volume of an infinitestimal washer is given by
# ## $$ dV = \pi (y_{\text{outer}}^2 - y_{\text{inner}}^2) dx $$

# %% [markdown]
# ## Average value
#
# ### ***Average value of $f(x)$***
#
# ### The average value of a function $f(x)$ on an interval $a \leq x \leq b$ is given by
# ## $$ \frac{1}{b - a} \int_{a}^{b} f(x) dx $$
#
# ### ***Average value and average rate of change***
#
# ### Fundamental Theorem of calculus tells us that the average rate of change of $y$ over $a \leq t \leq b$ is the ***same*** as the average value of $y'$ over $a \leq t \leq b$.
#
# ## $$ \operatorname{ Ave }(y') = \frac{1}{b-a} \int_{a}^{b} y'(t) dt = \frac{y(b) - y(a)}{b - a} $$
# ## $$ = \text{average rate of change of }\, y(t) $$
#
# ### ***Weighted average***
# ### The ***weighted average*** value of a function $f(x)$, weighted by a weight function $w(x)$ on an interval $a \leq x \leq b$ is given by
# ## $$ \frac{\int_{a}^{b} f(x) w(x) dx}{\int_{a}^{b} w(x) dx} $$
#
# ### ***Center of mass***
#
# ### ***1-dimentional***
# ### For a 1-dimensional rod of length $L$ with linear density function $\lambda(x)$ (measured in mass per unit length), the center of mass is the weighted average:
# ## $$ x_c = \frac{\int_{0}^{L} x \lambda(x) dx}{\int_{0}^{L} \lambda(x) dx} $$
#
# ### ***2-dimentional***
# ### For a 2-dimensional region whose mass is proportional to area, the center of mass, or centroid $(\bar{x}, \bar{y})$, is the weighted average of the position with respect to the area. The $x$- and $y$- coordinates of the centroid are computed by the following integrals:
# ## $$ \bar{x} = \frac{\int_{a}^{b} x dA}{\int_{a}^{b} dA} $$
# ## $$ \bar{y} = \frac{\int_{a}^{b} y dA}{\int_{a}^{b} dA} $$
# ### where $dA$ is the infinitesimal area, and we must define the limits of integration so that we integrate over the entire region with respect to $x$ or $y$ respectively.
#
# ### ***Work, heat, and energy***
# ### ***Work*** is done on an object when ***energy*** is transferred to that object.
# ### - ***Work***, ***heat***, and ***energy*** have the same units, but we typically measure them differently.
# ### - We measure ***work*** in Newton-meters (N⋅m).
# ### - We measure ***heat*** in calories (cal).
# ### - And we measure ***energy*** in Joules (J).
# ### James Joule recognized and measured the relationship between heat energy and mechanical work.
# ## $$ 1 \text{cal} = 4.186 J = 4.186 N \cdot m $$
# ### The approach to solving problems involving work, heat, or energy is the same, and involves computing an integral.
# ### A common example of mechanical work is when a force is applied over a distance. This force applied to the object transfers energy in the form of kinetic or potential energy. In this case, the formula for work is given by
# ## $$ W = \int F dx $$
#
# ### In the cauldron example, heat energy was transferred to the water in the cauldron. We measured the work done, or the energy transferred, by measuring the total change in temperature $T$:
#
# ## $$ \int T dV $$

# %% [markdown]
# ## Probability
#
# ### ***Discrete probability***
# ### Discrete probability measures the likelihood of a specified outcome.
# ## $$ \text{Discrete Probability} = \frac{\text{\# specified outcomes}}{\text{\# all possible outcomes}} $$
# ### Note this means that the probability is a positive fraction that is less than or equal to $1$.
#
# ### ***Distributions***
# ### A ***distribution*** is a nonnegative function $w(x)$ that approximates the discrete distribution. The area under a distribution measures the probability that an event occurs.
# ## $$ P(a < x < b) = \frac{\int_{a}^{b} w(x) dx}{\int_{-\infty}^{\infty} w(x) dx} $$
#
# ### For commonly used distributions, it is common to rescale the function.
# ### Since
# ## $$ \int_{-\infty}^{\infty} w(x) dx = C $$
# ### is a finite constant, we define a new function
# ## $$ p(x)=\frac{w(x)}{C} $$
# ### This new function $p(x)$ had the property that
# ## $$ \int_{-\infty}^{\infty} p(x) dx = 1 $$
# ### A ***probability distribution*** or a ***probability density function*** is defined as a nonnegative function $p(x)$ defined on $-\infty<x<\infty$ with the property that
# ## $$ \int_{-\infty}^{\infty} p(x) dx = 1 $$
# ### In this case, the probability of the outcome $a<x<b$ is defined as:
# ## $$ P(a < x < b) = \int_{a}^{b} p(x) dx $$

# %% [markdown]
# ### ***Normal distribution***
# ## $$ p(x) = \frac{1}{\sigma \sqrt{2\pi}} e^{\frac{-(x-\mu)^2}{2\sigma^2}}, \quad -\infty < x < \infty $$
# ### where the expected value is $\mu$ and the standard deviation is $\sigma$.
#
# ### The normal distribution is used to compute probabilities across all sciences, social sciences, and engineering, for example in measurements in astronomy, biology, chemistry, or physics. You may have seen it used for grades on an exam, or with respect to heights or weights of people in a population.

# %% [markdown]
# ### ***Exponential distribution***
# ## $$ p(t) = a e^{-a t}, \quad 0 \leq t < \infty \quad (\text{and}\, p(t) = 0, t<0) $$
# ### where the expected value is $\frac{1}{a}$
# ### Note that
# ## $$ \int_{0}^{\infty} a e^{-a t} dt = 1 $$
# ### , so this is a probability distribution. The exponential distribution is used to compute the probability of a “waiting time" between events, such as the arrival of a bus, the decay of a radioactive particle, or the time between phone calls during business hours.

# %% [markdown]
# ### ***Expected Value***
#
# ### Given a probability distribution $p(x)$ such that
# ## $$ \int_{-\infty}^{\infty} p(x) dx = 1 $$
# ### , the ***expected value***, $E$, also known as the ***mean***.
# ## $$ \text{Expected Value}\, = E = \int_{-\infty}^{\infty} x p(x) dx $$
# ### Note that the expected value is completely analogous to center of mass. Here we do not need to divide by the total integral of the probability distribution since the integral $\int_{-\infty}^{\infty} p(x) dx$ is normalized to be equal to $1$
#
#
# ### ***Variance***
# ### Given a probability distribution $p(x)$ with
# ## $$ \int_{-\infty}^{\infty} p(x) dx = 1 $$
# ### , and whose expected value is $E$, the ***variance***, $V$, measures the average spread of outcomes from the expected value.
# ## $$ \text{Variance}\, = V = \int_{-\infty}^{\infty} (x - E)^2 p(x) dx $$
# ### The ***standard deviation***, $\sigma$, is the square root of the variance:
# ## $$ \sigma = \sqrt{V} $$
#
#
# ### ***Area under the curve***
# ### The area under half of the bell curve is:
# ## $$ \int_{0}^{\infty} e^{-x^{2}} dx = \sqrt{\pi}/2 $$

# %% [markdown]
# ## Numerical integration
#
# ### ***Riemann sums: left and right***
# ### To approximate the integral
# ## $$ \int_{a}^{b} f(x) dx $$
# ### - Subdivide the interval into $n$ pieces $a=x_0<x_1<\ldots<x_{n-1}<x_n=b$.
# ### - Let $y_0 = f(x_0),y_1 = f(x_1),\ldots,y_{n-1} = f(x_{n-1}),$ and $y_n = f(x_n)$
# ### - $\Delta x = \frac{b-1}{n}$
# ### - ***Left Riemann Sum*** $\int_{a}^{b} f(x) dx \approx \Delta x (y_0 + y_1 + \ldots + y_{n-1})$
# ### - ***Right Riemann Sum*** $\int_{a}^{b} f(x) dx \approx \Delta x (y_1 + y_2 + \ldots + y_{n})$
#
#
# ### ***Riemann sums: Midpoint rule***
# ### To approximate the integral $\int_{a}^{b} f(x) dx$
# ### - Subdivide the interval into $n$ pieces $a=x_0<x_1<\ldots<x_{n-1}<x_n=b$.
# ### - Find the value of the function on the midpoint of each interval
# ## $$ \tilde{y_1} = f(\frac{x_0 + x_1}{2}),\tilde{y_2} = f(\frac{x_1 + x_2}{2}),\ldots,\tilde{y_n} = f(\frac{x_{n-1} + x_n}{2}), $$
# ### - $ \Delta x = \frac{b-a}{n} $.
# ### ***Midpoint rule*** $\int_{a}^{b} f(x) dx \approx \Delta x (\tilde{y_1} + \tilde{y_2} + \ldots + \tilde{y_n})$
#
#
# ### ***Trapezoidal Rule***
# ### To approximate the integral $\int_{a}^{b} f(x) dx$:
# ### - Subdivide the interval into $n$ pieces $a=x_0<x_1<\ldots<x_{n-1}<x_n=b$.
# ### - Let $y_0 = f(x_0), y_1=f(x_1),\ldots,y_{n-1}=f(x_{n-1}),$ and $y_n = f(x_n)$
# ### - $\Delta x = \frac{b-a}{n}$
# ### - ***Trapezoidal Rule*** $\int_{a}^{b} f(x) dx \approx \Delta x (\frac{1}{2} y_0 + y_1 + y_2 + y_3 + \ldots + y_{n-2} + y_{n-1} + \frac{1}{2} y_n)$
#
# ### ***Simpson's Rule***
# ### To approximate the integral $\int_{a}^{b} f(x) dx$:
# ### - Subdivide the interval into $n$ pieces ($n$ must be even) $a=x_0<x_1<\ldots<x_{n-1}<x_n=b$.
# ### - Let $y_0 = f(x_0), y_1=f(x_1),\ldots,y_{n-1}=f(x_{n-1}),$ and $y_n = f(x_n)$
# ### - $\Delta x = \frac{b-a}{n}$
# ### - ***Simpson's Rule*** $\int_{a}^{b} f(x) dx \approx \frac{\Delta x}{3} (y_0 + 4 y_1 + 2 y_2 + 4 y_3 + \ldots + 2 y_{n-2} + 4 y_{n-1} + y_n)$
#
# ### ***Error Bounds***
#
# ### - ***Error bound of Trapezoidal Rule***
# ### Suppose $|f''(x)| \leq M$ for $a \leq x \leq b$. Then the error of the Trapezoidal Rule over $n$ subintervals is given by
# ## $$ |E_{T}| \leq \frac{M(b - a)^3}{12 n^2} $$
#
# ### - ***Error bound of Midpoint Rule***
# ### Suppose $|f''(x)| \leq M$ for $a \leq x \leq b$. The the error of the Midpoint Rule over $n$ subintervals is given by
# ## $$ |E_{M}| \leq \frac{M(b-a)^3}{24 n^2} $$
#
# ### - ***Error bound of Simpson's Rule***
# ### Suppose $|f^{(4)}(x)| \leq M$ for $a \leq x \leq b$. The the error of the Simpson's Rule over $n$ subintervals is given by
# ## $$ |E_{S}| \leq \frac{M(b-a)^5}{180 n^4} $$
